# %%
e0 = 3.77E-2
I=e0**2
print(I)
IWcm2=I*3.51E16
print('%e' % IWcm2)

freq = 4.3E-3 #fréquence du champ

freqcm1=freq*2.19475E5
print(freqcm1)
# Out:
# 0.0014212899999999997
# 4.988728e+13
# 943.7425

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
i=7
tvec=[]
rmoy1=[]
f=open("fort."+str(i))
for line in f:
    tvec.append(float(line[0:25]))
    rmoy1.append(float(line[25:49]))
i=8
tvec2=[]
rmoy2=[]
f=open("fort."+str(i))
for line in f:
    tvec2.append(float(line[0:25]))
    rmoy2.append(float(line[25:49]))
    
plt.plot(tvec,rmoy1,tvec2,rmoy2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  
i=1000
tvec=[]
pbound1=[]
f=open("fort."+str(i))
for line in f:
    tvec.append(float(line[0:25]))
    pbound1.append(float(line[25:49]))
i=1001
tvec2=[]
pbound2=[]
f=open("fort."+str(i))
for line in f:
    tvec2.append(float(line[0:25]))
    pbound2.append(float(line[25:49]))
    
plt.plot(tvec,100*np.array(pbound1),tvec2,100**np.array(pbound2))
plt.ylabel(r'$P_{Li\acute{e}e}$ (%)')
plt.xlabel('Time (u.a.)')
plt.savefig('PBOUND.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
xeq=2
w_cm=943.3
w_ua=w_cm/2.19475E5
T_ua=2*np.pi/w_ua
t=np.linspace(0,3*T_ua,1000)
delta=1.5*np.pi
Iwcm2=5E13
E0ua=(Iwcm2/3.51E16)**(0.50)
print('E0ua = '+str(E0ua)+' u.a.')
champ=E0ua*np.cos(w_ua*t+delta)


#plt.plot([0, 0], [0, 0.04], 'k-', lw=2)
diff=0
gamma=5
t2=np.linspace(-30,30,1000)

xuv1=0.3*1/np.pi*0.5*gamma/((t2-0)**2+(0.5*gamma)**2)
t3=np.linspace(T_ua/4-30,T_ua/4+30,1000)
xuv2=0.3*1/np.pi*0.5*gamma/((t3-(T_ua/4))**2+(0.5*gamma)**2)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t,champ,'red',t2,xuv1,'blue',t3,xuv2,'blue')
plt.ylabel('E(u.a.)')
plt.xlabel('Time(u.a.)')
ax.axis([-200,3*T_ua,-0.04,0.04])
plt.text(0-diff, -0.01, r'$\tau_1$')
plt.text(T_ua/4-diff, -0.01, r'$\tau_2$')
plt.text(T_ua/2-diff, -0.01, r'$\tau_3$')
plt.text(3*T_ua/4-diff, -0.01, r'$\tau_4$')
plt.plot([0,T_ua/4,T_ua/2,3*T_ua/4],[0,0,0,0],'o')
ax2 = ax.twinx()
ax2.plot(np.array(tvec)+T_ua/4,(np.array(rmoy1)-xeq),tvec2,(np.array(rmoy2)-xeq))
ax2.axis([-200,3*T_ua,-12,12])
ax2.set_ylabel(r'$R-R_{eq}$ (u.a.)')
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
#ax.spines['left'].set_position('2-tuple')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
diff=50


#plt.plot(tvec,rmoy1,tvec2,rmoy2)

#plt.savefig('/home/francois/IR_field_and_XUV.png')
plt.savefig('IR_XUV_Rmoy.png')
plt.show()
# Out:
# E0ua = 0.03774256780481986 u.a.

# %%
import numpy as np
import matplotlib.pyplot as plt
xeq=2
w_cm=943.3
w_ua=w_cm/2.19475E5
T_ua=2*np.pi/w_ua
t=np.linspace(0,3*T_ua,1000)
delta=1.5*np.pi
Iwcm2=5E13
E0ua=(Iwcm2/3.51E16)**(0.50)
print('E0ua = '+str(E0ua)+' u.a.')
champ=E0ua*np.cos(w_ua*t+delta)


#plt.plot([0, 0], [0, 0.04], 'k-', lw=2)

gamma=5
t2=np.linspace(-30,30,1000)

xuv1=0.3*1/np.pi*0.5*gamma/((t2-0)**2+(0.5*gamma)**2)
t3=np.linspace(T_ua/4-30,T_ua/4+30,1000)
xuv2=0.3*1/np.pi*0.5*gamma/((t3-(T_ua/4))**2+(0.5*gamma)**2)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.plot(t,champ,'red',t2,xuv1,'blue',t3,xuv2,'blue')
plt.plot(t,champ,'red',t2,xuv1,'blue')
plt.ylabel('E(u.a.)')
#plt.xlabel('Time(u.a.)')
ax.axis([-200,3*T_ua,-0.04,0.04])
plt.text(0-diff, -0.01, r'$\tau_1$')
plt.text(T_ua/4-diff, -0.01, r'$\tau_2$')
#plt.text(T_ua/2-diff, -0.01, r'$\tau_3$')
#plt.text(3*T_ua/4-diff, -0.01, r'$\tau_4$')
plt.plot([0,T_ua/4],[0,0],'o')
#plt.plot([0,T_ua/4,T_ua/2,3*T_ua/4],[0,0,0,0],'o')

plt.text(1800, -0.05, 'Temps (u.a.)')
ax2 = ax.twinx()
#ax2.plot(np.array(tvec)+T_ua/4,(np.array(rmoy1)-xeq),tvec2,(np.array(rmoy2)-xeq))
ax2.plot(tvec2,(np.array(rmoy2)-xeq),'green')
ax2.axis([-200,3*T_ua,-12,12])
ax2.set_ylabel(r'$R-R_{eq}$ (u.a.)')
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
#ax.spines['left'].set_position('2-tuple')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
diff=50


#plt.plot(tvec,rmoy1,tvec2,rmoy2)

#plt.savefig('/home/francois/IR_field_and_XUV.png')
plt.savefig('IR_XUV_Rmoy1.png')
plt.show()
# Out:
# E0ua = 0.03774256780481986 u.a.

# %%
import numpy as np
import matplotlib.pyplot as plt
xeq=2
w_cm=943.3
w_ua=w_cm/2.19475E5
T_ua=2*np.pi/w_ua
t=np.linspace(0,3*T_ua,1000)
delta=1.5*np.pi
Iwcm2=5E13
E0ua=(Iwcm2/3.51E16)**(0.50)
print('E0ua = '+str(E0ua)+' u.a.')
champ=E0ua*np.cos(w_ua*t+delta)


#plt.plot([0, 0], [0, 0.04], 'k-', lw=2)

gamma=5
t2=np.linspace(-30,30,1000)

xuv1=0.3*1/np.pi*0.5*gamma/((t2-0)**2+(0.5*gamma)**2)
t3=np.linspace(T_ua/4-30,T_ua/4+30,1000)
xuv2=0.3*1/np.pi*0.5*gamma/((t3-(T_ua/4))**2+(0.5*gamma)**2)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t,champ,'red',t3,xuv2,'blue')
#plt.plot(t,champ,'red',t2,xuv1,'blue')
plt.ylabel('E(u.a.)')
#plt.xlabel('Time(u.a.)')
ax.axis([-200,3*T_ua,-0.04,0.04])
#plt.text(0-diff, -0.01, r'$\tau_1$')
plt.text(T_ua/4-diff, -0.01, r'$\tau_2$')
plt.text(T_ua/2-diff, -0.01, r'$\tau_3$')
#plt.text(3*T_ua/4-diff, -0.01, r'$\tau_4$')
plt.plot([T_ua/4,T_ua/2],[0,0],'o')
#plt.plot([0,T_ua/4,T_ua/2,3*T_ua/4],[0,0,0,0],'o')

plt.text(1800, -0.05, 'Temps (u.a.)')
ax2 = ax.twinx()
ax2.plot(np.array(tvec)+T_ua/4,(np.array(rmoy1)-xeq))
#ax2.plot(tvec2,(np.array(rmoy2)-xeq),'green')
ax2.axis([-200,3*T_ua,-12,12])
ax2.set_ylabel(r'$R-R_{eq}$ (u.a.)')
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
#ax.spines['left'].set_position('2-tuple')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
diff=50


#plt.plot(tvec,rmoy1,tvec2,rmoy2)

#plt.savefig('/home/francois/IR_field_and_XUV.png')
plt.savefig('IR_XUV_Rmoy2.png')
plt.show()
# Out:
# E0ua = 0.03774256780481986 u.a.

# %%
"""
===========================
Plots with different scales
===========================

Demonstrate how to do two plots on the same axes with different left and
right scales.

The trick is to use *two different axes* that share the same *x* axis.
You can use separate `matplotlib.ticker` formatters and locators as
desired since the two axes are independent.

Such axes are generated by calling the `Axes.twinx` method.  Likewise,
`Axes.twiny` is available to generate axes that share a *y* axis but
have different top and bottom scales.

The twinx and twiny methods are also exposed as pyplot functions.

"""

import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
t = np.arange(0.01, 10.0, 0.01)
s1 = np.exp(t)
ax1.plot(t, s1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('exp', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
s2 = np.sin(2 * np.pi * t)
ax2.plot(t, s2, 'r.')
ax2.set_ylabel('sin', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.show()
